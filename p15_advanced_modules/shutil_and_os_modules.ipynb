# %% [markdown]
# <br>
#
# ---
# ## <span style="color:mediumturquoise">Opening and Reading Files</span>
# So far we've discussed how to open files manually, one by one. Let's explore how we can open files programatically.

# %% [markdown]
# <br>
#
# ---
# ### <span style="color:palegreen">Getting Directories</span>
#
# Python has a built-in [os module](https://docs.python.org/3/library/os.html) that allows us to use operating system dependent functionality.
#
# You can get the current directory:

# %%
import os

os.getcwd()
# Out:
# 'c:\\Users\\James\\Desktop\\Python_Bootcamp\\Python_Bootcamp_Notebooks\\p15_advanced_modules'

# %% [markdown]
# <br>
#
# ---
# ### <span style="color:palegreen">Create Practice File</span>
#
# We will begin by creating a practice text file that we will be using for demonstration.

# %%
myfile = open('practice.txt', 'w+')
myfile.write('This is a test string')
myfile.close()

# %% [markdown]
# <br>
#
# ---
# ### <span style="color:palegreen">Listing Files in a Directory</span>
#
# You can also use the os module to list directories.

# %%
# files in current directory
os.listdir()

# Files in the provided directory
os.listdir('c:\\Users\\James\\Desktop\\Python_Bootcamp\\Python_Bootcamp_Notebooks')
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '.vscode',
#  'env',
#  'Explanation.txt',
#  'mymodule.py',
#  'myprogram.py',
#  'p10_name_and_main',
#  'p11_error_handling',
#  'p12_blackjack_project',
#  'p13_decorators',
#  'p14_generators',
#  'p15_advanced_modules',
#  'p4_objects_and_data_structures',
#  'p5_statements',
#  'p6_methods_and_functions',
#  'p8_OOP',
#  'p9_MyMainPackage',
#  'README.md']

# %% [markdown]
# <br>
#
# ---
# ### <span style="color:palegreen">Moving Files</span>
#
# You can use the built-in **shutil** module to to move files to different locations. Keep in mind, there are permission restrictions, for example if you are logged in a User A, you won't be able to make changes to the top level Users folder without the proper permissions, [more info](https://stackoverflow.com/questions/23253439/shutil-movescr-dst-gets-me-ioerror-errno-13-permission-denied-and-3-more-e)
# You can also use the os module to list directories.

# %%
import shutil

shutil.move('practice.txt', 'c:\\Users\\James')
# Out:
# 'c:\\Users\\James\\practice.txt'

# %% [markdown]
# <br>
#
# ---
# ### <span style="color:palegreen">Deleting Files</span>
# ____
# **NOTE: The os module provides 3 methods for deleting files:**
# * os.unlink(path) which deletes a file at the path your provide
# * os.rmdir(path) which deletes a folder (folder must be empty) at the path your provide
# * shutil.rmtree(path) this is the most dangerous, as it will remove all files and folders contained in the path.
# **All of these methods can not be reversed! Which means if you make a mistake you won't be able to recover the file. Instead we will use the send2trash module. A safer alternative that sends deleted files to the trash bin instead of permanent removal.**
# ___
#
# Install the send2trash module with:
#
#     pip install send2trash
#
# at your command line.

# %%
import send2trash

shutil.move('c:\\Users\\James\\practice.txt', os.getcwd())
os.listdir()
# Out:
# ['advanced_modules.ipynb', 'practice.txt', 'shutil_and_os_modules.ipynb']

# %%
send2trash.send2trash('practice.txt')
os.listdir()
# Out:
# ['advanced_modules.ipynb', 'shutil_and_os_modules.ipynb']

# %% [markdown]
# <br>
#
# ---
# ### <span style="color:palegreen">Walking through a directory</span>
#
# Often you will just need to "walk" through a directory, that is visit every file or folder and check to see if a file is in the directory, and then perhaps do something with that file. Usually recursively walking through every file and folder in a directory would be quite tricky to program, but luckily the os module has a direct method call for this called os.walk(). Let's explore how it works.

# %%
my_file_path = 'c:\\Users\\James\\Desktop\\Python_Bootcamp\\Python_Bootcamp_Notebooks'

for folder, sub_folders, files in os.walk(my_file_path):
    print(f"Currently looking at {folder}")
    print("\n")
    
    print("The subfolders are: ")
    for sub_fold in sub_folders:
        print(f"\t Subfolder {sub_fold}")
    
    print("\n")
    print("The files are: ")
    for file in files:
        print(f"\t File: {file}")

    print("\n")
# Out:
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks
#
#
# The subfolders are:
# 	 Subfolder .git
# 	 Subfolder .ipynb_checkpoints
# 	 Subfolder .vscode
# 	 Subfolder env
# 	 Subfolder p10_name_and_main
# 	 Subfolder p11_error_handling
# 	 Subfolder p12_blackjack_project
# 	 Subfolder p13_decorators
# 	 Subfolder p14_generators
# 	 Subfolder p15_advanced_modules
# 	 Subfolder p4_objects_and_data_structures
# 	 Subfolder p5_statements
# 	 Subfolder p6_methods_and_functions
# 	 Subfolder p8_OOP
# 	 Subfolder p9_MyMainPackage
#
#
# The files are:
# 	 File: .gitignore
# 	 File: Explanation.txt
# 	 File: mymodule.py
# 	 File: myprogram.py
# 	 File: README.md
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git
#
#
# The subfolders are:
# 	 Subfolder hooks
# 	 Subfolder info
# 	 Subfolder logs
# 	 Subfolder objects
# 	 Subfolder refs
#
#
# The files are:
# 	 File: COMMIT_EDITMSG
# 	 File: config
# 	 File: description
# 	 File: HEAD
# 	 File: index
# 	 File: packed-refs
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\hooks
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: applypatch-msg.sample
# 	 File: commit-msg.sample
# 	 File: fsmonitor-watchman.sample
# 	 File: post-update.sample
# 	 File: pre-applypatch.sample
# 	 File: pre-commit.sample
# 	 File: pre-merge-commit.sample
# 	 File: pre-push.sample
# 	 File: pre-rebase.sample
# 	 File: pre-receive.sample
# 	 File: prepare-commit-msg.sample
# 	 File: push-to-checkout.sample
# 	 File: update.sample
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\info
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: exclude
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\logs
#
#
# The subfolders are:
# 	 Subfolder refs
#
#
# The files are:
# 	 File: HEAD
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\logs\refs
#
#
# The subfolders are:
# 	 Subfolder heads
# 	 Subfolder remotes
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\logs\refs\heads
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: main
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\logs\refs\remotes
#
#
# The subfolders are:
# 	 Subfolder origin
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\logs\refs\remotes\origin
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: HEAD
# 	 File: main
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects
#
#
# The subfolders are:
# 	 Subfolder 01
# 	 Subfolder 09
# 	 Subfolder 0a
# 	 Subfolder 0b
# 	 Subfolder 0d
# 	 Subfolder 12
# 	 Subfolder 13
# 	 Subfolder 14
# 	 Subfolder 17
# 	 Subfolder 19
# 	 Subfolder 1e
# 	 Subfolder 21
# 	 Subfolder 25
# 	 Subfolder 28
# 	 Subfolder 2a
# 	 Subfolder 2d
# 	 Subfolder 2e
# 	 Subfolder 2f
# 	 Subfolder 37
# 	 Subfolder 3f
# 	 Subfolder 41
# 	 Subfolder 42
# 	 Subfolder 46
# 	 Subfolder 47
# 	 Subfolder 48
# 	 Subfolder 4a
# 	 Subfolder 4f
# 	 Subfolder 50
# 	 Subfolder 51
# 	 Subfolder 53
# 	 Subfolder 54
# 	 Subfolder 5d
# 	 Subfolder 5e
# 	 Subfolder 5f
# 	 Subfolder 63
# 	 Subfolder 6b
# 	 Subfolder 6c
# 	 Subfolder 6d
# 	 Subfolder 6e
# 	 Subfolder 71
# 	 Subfolder 73
# 	 Subfolder 77
# 	 Subfolder 78
# 	 Subfolder 7c
# 	 Subfolder 7f
# 	 Subfolder 80
# 	 Subfolder 88
# 	 Subfolder 8d
# 	 Subfolder 92
# 	 Subfolder 94
# 	 Subfolder 96
# 	 Subfolder 98
# 	 Subfolder 99
# 	 Subfolder 9a
# 	 Subfolder 9c
# 	 Subfolder 9e
# 	 Subfolder 9f
# 	 Subfolder a1
# 	 Subfolder a2
# 	 Subfolder a3
# 	 Subfolder a4
# 	 Subfolder a9
# 	 Subfolder aa
# 	 Subfolder ab
# 	 Subfolder b0
# 	 Subfolder b3
# 	 Subfolder b5
# 	 Subfolder b7
# 	 Subfolder bd
# 	 Subfolder ca
# 	 Subfolder cd
# 	 Subfolder d4
# 	 Subfolder d6
# 	 Subfolder db
# 	 Subfolder df
# 	 Subfolder e1
# 	 Subfolder e3
# 	 Subfolder e5
# 	 Subfolder e6
# 	 Subfolder ec
# 	 Subfolder ee
# 	 Subfolder f4
# 	 Subfolder f8
# 	 Subfolder f9
# 	 Subfolder fa
# 	 Subfolder fb
# 	 Subfolder fc
# 	 Subfolder fd
# 	 Subfolder info
# 	 Subfolder pack
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\01
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 7f4741ef1de1ccdbb0a73c0d153c4849b8f1ba
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\09
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 05770d45e49f4edbbaee6db2dacffd2c29d989
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\0a
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: b4d1fa36596e6ae99a83b7b814c6624dc3cd14
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\0b
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 0b3a70f4e2ade69c29463aa85f9680d35a7d4f
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\0d
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 2cfa11a87ccb5e9f874c326ad7fcc1107247c2
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\12
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: b1718e3fad29df7e51bc1c8d8f24448282cb2e
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\13
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: c03ffa0b18cda36dd97f6736d60bf0dd3af875
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\14
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: a6311a0ecfd96683a774b1a490d63931f05029
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\17
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: e15f27ec2bb23f50627f046a7e8d1b225be974
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\19
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: eb661e7f0a1e49175c986c779d9e159d015d72
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\1e
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 6bde49aaf8943826f86070c6e73cf703627eff
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\21
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 8d3a30a3ca0d3018e74a934723b5d2411bce31
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\25
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 3365822868bba8a41c2a457b3bf3530aa6d492
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\28
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 79a178a08c3520b375b1fcd7f58b62d32c5597
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\2a
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 9a0cd6593ef00a24ebeb20c72bd08bc58732a6
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\2d
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 4d2f5f22560b46fceb2e10ba346a7a90cc488a
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\2e
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: db8840a92f8296b8eb9dd1d609ab6734b4b5ea
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\2f
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 6418c4a74d08e76c3bd532c2259228fd4c8da2
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\37
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: d077444a82c84416b576c58422cd16d9c5203f
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\3f
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 41c92ad42b054aae3cd6866ac66ef10c65ddd7
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\41
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: f7598fe50f8b9a30eb79625685845ae82167e7
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\42
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 6df5434f0dde1849b8181b8db49ed6f31c75a4
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\46
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 1b4741bc6913d47513d463db67a2aa779c2f1d
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\47
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 9276883698a1c2644109a1292e4f935ca0c35d
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\48
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 739301070e7c3dff728984f0e1f00c15e7b386
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\4a
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 25aef1c91d4f1348dde1b619ffdbd284295e09
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\4f
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 6ac8c69bfc49914f86e80164840249a8c4e2d5
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\50
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 75e79203906fcadb0834a97010aeae66568854
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\51
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: d661511433790a3ca7fbbf08b0bfc0d7de5475
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\53
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: e6c092e1c887bef49f9f9c0837f5ebd0bbb7da
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\54
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: c1f0af473c76846827d888e06b81f76611f089
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\5d
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 80a2fd943a55068269e6875941730c3bbde979
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\5e
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: fb7e5c228378ce6b845570e7477e2f5aad7167
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\5f
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: ca64e80a31207301752764778541a5b6912e4d
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\63
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: e0a6681a62aaff518ee6a59b858c6aab5c8160
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\6b
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 70a9bffd7bcc491d129467f1012c1109caf887
# 	 File: 94d5182c62441e915fe5d2bfa23a4f5fb8d6d5
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\6c
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 3df16f17dd5319d6dea2a5d7b68955db27f6bc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\6d
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: a43986962c34fcbb3b5238d013b7e99260e3b0
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\6e
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 68ac4245443c5b0960b9620ceb63e6394b854a
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\71
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 0afbc71713e84afcfbaa580ab1502fc6302291
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\73
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 0bd269dbc05be28ea58f316c1f699f95e9159d
# 	 File: bb670df35b431a5f11abe808670d75e7fc70db
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\77
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 3a88aea37370cf8f647f2369568ca3d74eac27
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\78
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: c9c3c1775a6d38f2dedf12cb3d50e26d457f43
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\7c
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 47ee2a87758ac63abfce70a63c40ac43f821d6
# 	 File: 90f9644d36ad90219795249c08919d8fa44e36
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\7f
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: af5e49c5484f3d3f5eebc08b90a392698c233e
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\80
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: d60226779048e949e185a8479f301a7fa77796
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\88
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: e1e5c837b15a72abeca04b98c98893ed0fda7c
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\8d
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 41e59aa7f9632aafbb4135a013dc929643a886
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\92
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 1af1bb10f9674cac40a1a71e3ded2f0bd9bc5c
# 	 File: 4005a82a990686743d164768855c3275e486b5
# 	 File: 4684185697417027c1d577c0b33a6144c778c0
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\94
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 05ac4cc7d992cbf9d36b8424080dc45cb4492d
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\96
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 25f4345d1d508207923990e6b3d41d044e6148
# 	 File: 744ce8bf030ac10bee26f979b430e3d58baf14
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\98
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 793f2bf671fad03fc38ea3f5dff9750fb2c765
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\99
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 6ba6e6b95ea3861a1da43794384adc1b9320c7
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\9a
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: bcd01487eb6e0fbfd3862a2d8f7cf252a928ff
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\9c
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 3e31d1b60b669684decc12fce218563be5d014
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\9e
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: fafb382fe5736f331613ded538736a5fe4237e
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\9f
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 90d1c168eae64125911e60868d5667fa9e90cf
# 	 File: a369571a98bfe2f55bdf8acc8c96f54b6f4739
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\a1
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: bd1869ebbac998c6dad8869891ead8d656149d
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\a2
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 340f9185820ad2eff41a96218744c877273162
# 	 File: de5a60e5df3ad51a5baae21da5d2338adbcc64
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\a3
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 843e1c83bd824ae1020ed1a106db25a9db4855
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\a4
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 2ab23a9b5c2cdfbc797d9659f4be1fae7b9c22
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\a9
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 0312ae4e02c9542ce31dd9da68ae0d6296fe76
# 	 File: 5a648caa433bc3a0e1ebccbdc9bc0c17d03c99
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\aa
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 0d312e04b84ac5fb594875ea01d99b456f3dd4
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\ab
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 4723ba33a4da81e0cb78f73739b778ec105470
# 	 File: 73eced6ab11a3e91979343bfee5f6ec944334f
# 	 File: bc06ed780fc1f6ad7703f8bff71c738712f008
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\b0
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: a075b9e655192fc28fb257f08282b1d5ac485f
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\b3
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: e3b4d3be5117d6032bb53cde0362e852bb7f7a
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\b5
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 686080a608fad223118f731abccf6289fd80cc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\b7
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 413cd46b91ea1aa3c4a2c5039e5df1644afe5d
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\bd
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 20fe591e2bb1d67b3725b098b4e173b23258a6
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\ca
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 1987b056c0d4265decbbf77f1df9661b9e891a
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\cd
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: a7de011319eb0f84461662c1519cd1459532c2
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\d4
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 40caec0be6d48ac5eedffa3f18a5cf68eaa958
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\d6
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 90ce75b9a162a1b169a7a9671de6968c48b93c
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\db
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 077106dc0eed4d20481b6d7b16be4daa8bfc4c
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\df
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 3719dc5744301042a505c76847f1a42340ca59
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\e1
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 9c7a4f9a57b2e635b0950c1e07d2cbdd6bec18
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\e3
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: ae37d719264f4a509b982ac3d31ddc8e494c68
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\e5
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 0952dd152ba5fc288dd29333f40619920afd89
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\e6
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 9de29bb2d1d6434b8b29ae775ad8c2e48c5391
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\ec
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: c396cbd195fd13f998610495d83bacf88865a5
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\ee
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 7c1abc96b612e5c1313a84fcc1f90e27e01b2d
# 	 File: ac3bf20b8ce9b969887dbd5891a449b90a17ad
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\f4
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 79c696bad7d3306790b8c2ece5c415611b235a
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\f8
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: c111ba4dbe1d67a35becd5eb7f7281937a7d4d
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\f9
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 29dcba95303bc02767bfb611a1c35b58d7b8cc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\fa
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: cdf6a758d2a793a09e90985a453da5701d6edd
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\fb
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 3139394cb1da839a9104c71d01a29632c30333
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\fc
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: b13086c4101df075ed665aa170668fa433ae1d
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\fd
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 0472565e94fec161d037d14e85d9fbfafd3868
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\info
#
#
# The subfolders are:
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\objects\pack
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: pack-cab276ed83a907f5ea0b5e9d1c9617e13f12699d.idx
# 	 File: pack-cab276ed83a907f5ea0b5e9d1c9617e13f12699d.pack
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\refs
#
#
# The subfolders are:
# 	 Subfolder heads
# 	 Subfolder remotes
# 	 Subfolder tags
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\refs\heads
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: main
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\refs\remotes
#
#
# The subfolders are:
# 	 Subfolder origin
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\refs\remotes\origin
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: HEAD
# 	 File: main
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.git\refs\tags
#
#
# The subfolders are:
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.ipynb_checkpoints
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: IO_Tutorial-checkpoint.ipynb
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\.vscode
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: launch.json
# 	 File: settings.json
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env
#
#
# The subfolders are:
# 	 Subfolder Include
# 	 Subfolder Lib
# 	 Subfolder Scripts
# 	 Subfolder share
#
#
# The files are:
# 	 File: pyvenv.cfg
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Include
#
#
# The subfolders are:
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib
#
#
# The subfolders are:
# 	 Subfolder site-packages
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages
#
#
# The subfolders are:
# 	 Subfolder adodbapi
# 	 Subfolder astroid
# 	 Subfolder astroid-2.9.0.dist-info
# 	 Subfolder backcall
# 	 Subfolder backcall-0.2.0.dist-info
# 	 Subfolder black
# 	 Subfolder black-21.12b0.dist-info
# 	 Subfolder blackd
# 	 Subfolder black_primer
# 	 Subfolder blib2to3
# 	 Subfolder click
# 	 Subfolder click-8.0.3.dist-info
# 	 Subfolder colorama
# 	 Subfolder colorama-0.4.4.dist-info
# 	 Subfolder dateutil
# 	 Subfolder debugpy
# 	 Subfolder debugpy-1.5.1.dist-info
# 	 Subfolder decorator-5.1.0.dist-info
# 	 Subfolder entrypoints-0.3.dist-info
# 	 Subfolder et_xmlfile
# 	 Subfolder et_xmlfile-1.1.0.dist-info
# 	 Subfolder ipykernel
# 	 Subfolder ipykernel-6.6.0.dist-info
# 	 Subfolder IPython
# 	 Subfolder ipython-7.30.1.dist-info
# 	 Subfolder isapi
# 	 Subfolder isort
# 	 Subfolder isort-5.10.1.dist-info
# 	 Subfolder jedi
# 	 Subfolder jedi-0.18.1.dist-info
# 	 Subfolder jupyter_client
# 	 Subfolder jupyter_client-7.1.0.dist-info
# 	 Subfolder jupyter_core
# 	 Subfolder jupyter_core-4.9.1.dist-info
# 	 Subfolder lazy_object_proxy
# 	 Subfolder lazy_object_proxy-1.7.1.dist-info
# 	 Subfolder matplotlib_inline
# 	 Subfolder matplotlib_inline-0.1.3.dist-info
# 	 Subfolder mccabe-0.6.1.dist-info
# 	 Subfolder mypy_extensions-0.4.3.dist-info
# 	 Subfolder nest_asyncio-1.5.4.dist-info
# 	 Subfolder numpy
# 	 Subfolder numpy-1.21.5.dist-info
# 	 Subfolder openpyxl
# 	 Subfolder openpyxl-3.0.9.dist-info
# 	 Subfolder pandas
# 	 Subfolder pandas-1.3.5.dist-info
# 	 Subfolder parso
# 	 Subfolder parso-0.8.3.dist-info
# 	 Subfolder pathspec
# 	 Subfolder pathspec-0.9.0.dist-info
# 	 Subfolder pickleshare-0.7.5.dist-info
# 	 Subfolder pip
# 	 Subfolder pip-21.3.1.dist-info
# 	 Subfolder pkg_resources
# 	 Subfolder platformdirs
# 	 Subfolder platformdirs-2.4.1.dist-info
# 	 Subfolder prompt_toolkit
# 	 Subfolder prompt_toolkit-3.0.24.dist-info
# 	 Subfolder pygments
# 	 Subfolder Pygments-2.10.0.dist-info
# 	 Subfolder pylint
# 	 Subfolder pylint-2.12.2.dist-info
# 	 Subfolder pythonwin
# 	 Subfolder python_dateutil-2.8.2.dist-info
# 	 Subfolder pytz
# 	 Subfolder pytz-2021.3.dist-info
# 	 Subfolder pywin32-303.dist-info
# 	 Subfolder pywin32_system32
# 	 Subfolder pyzmq-22.3.0.dist-info
# 	 Subfolder pyzmq.libs
# 	 Subfolder send2trash
# 	 Subfolder Send2Trash-1.8.0.dist-info
# 	 Subfolder setuptools
# 	 Subfolder setuptools-56.0.0.dist-info
# 	 Subfolder six-1.16.0.dist-info
# 	 Subfolder toml
# 	 Subfolder toml-0.10.2.dist-info
# 	 Subfolder tomli
# 	 Subfolder tomli-1.2.3.dist-info
# 	 Subfolder tornado
# 	 Subfolder tornado-6.1.dist-info
# 	 Subfolder traitlets
# 	 Subfolder traitlets-5.1.1.dist-info
# 	 Subfolder typing_extensions-4.0.1.dist-info
# 	 Subfolder wcwidth
# 	 Subfolder wcwidth-0.2.5.dist-info
# 	 Subfolder win32
# 	 Subfolder win32com
# 	 Subfolder win32comext
# 	 Subfolder wrapt
# 	 Subfolder wrapt-1.13.3.dist-info
# 	 Subfolder zmq
# 	 Subfolder _distutils_hack
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: decorator.py
# 	 File: distutils-precedence.pth
# 	 File: entrypoints.py
# 	 File: ipykernel_launcher.py
# 	 File: jupyter.py
# 	 File: mccabe.py
# 	 File: mypy_extensions.py
# 	 File: nest_asyncio.py
# 	 File: pickleshare.py
# 	 File: pythoncom.py
# 	 File: PyWin32.chm
# 	 File: pywin32.pth
# 	 File: pywin32.version.txt
# 	 File: six.py
# 	 File: typing_extensions.py
# 	 File: _black_version.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\adodbapi
#
#
# The subfolders are:
# 	 Subfolder examples
# 	 Subfolder test
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: adodbapi.py
# 	 File: ado_consts.py
# 	 File: apibase.py
# 	 File: is64bit.py
# 	 File: license.txt
# 	 File: process_connect_string.py
# 	 File: readme.txt
# 	 File: remote.py
# 	 File: schema_table.py
# 	 File: setup.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\adodbapi\examples
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: db_print.py
# 	 File: db_table_names.py
# 	 File: xls_read.py
# 	 File: xls_write.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\adodbapi\examples\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: db_print.cpython-39.pyc
# 	 File: db_table_names.cpython-39.pyc
# 	 File: xls_read.cpython-39.pyc
# 	 File: xls_write.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\adodbapi\test
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: adodbapitest.py
# 	 File: adodbapitestconfig.py
# 	 File: dbapi20.py
# 	 File: is64bit.py
# 	 File: setuptestframework.py
# 	 File: test_adodbapi_dbapi20.py
# 	 File: tryconnection.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\adodbapi\test\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: adodbapitest.cpython-39.pyc
# 	 File: adodbapitestconfig.cpython-39.pyc
# 	 File: dbapi20.cpython-39.pyc
# 	 File: is64bit.cpython-39.pyc
# 	 File: setuptestframework.cpython-39.pyc
# 	 File: test_adodbapi_dbapi20.cpython-39.pyc
# 	 File: tryconnection.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\adodbapi\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: adodbapi.cpython-39.pyc
# 	 File: ado_consts.cpython-39.pyc
# 	 File: apibase.cpython-39.pyc
# 	 File: is64bit.cpython-39.pyc
# 	 File: process_connect_string.cpython-39.pyc
# 	 File: remote.cpython-39.pyc
# 	 File: schema_table.cpython-39.pyc
# 	 File: setup.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\astroid
#
#
# The subfolders are:
# 	 Subfolder brain
# 	 Subfolder interpreter
# 	 Subfolder nodes
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: arguments.py
# 	 File: astroid_manager.py
# 	 File: bases.py
# 	 File: builder.py
# 	 File: const.py
# 	 File: context.py
# 	 File: decorators.py
# 	 File: exceptions.py
# 	 File: helpers.py
# 	 File: inference.py
# 	 File: inference_tip.py
# 	 File: manager.py
# 	 File: mixins.py
# 	 File: modutils.py
# 	 File: node_classes.py
# 	 File: objects.py
# 	 File: protocols.py
# 	 File: raw_building.py
# 	 File: rebuilder.py
# 	 File: scoped_nodes.py
# 	 File: test_utils.py
# 	 File: transforms.py
# 	 File: util.py
# 	 File: _ast.py
# 	 File: __init__.py
# 	 File: __pkginfo__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\astroid\brain
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: brain_argparse.py
# 	 File: brain_attrs.py
# 	 File: brain_boto3.py
# 	 File: brain_builtin_inference.py
# 	 File: brain_collections.py
# 	 File: brain_crypt.py
# 	 File: brain_ctypes.py
# 	 File: brain_curses.py
# 	 File: brain_dataclasses.py
# 	 File: brain_dateutil.py
# 	 File: brain_fstrings.py
# 	 File: brain_functools.py
# 	 File: brain_gi.py
# 	 File: brain_hashlib.py
# 	 File: brain_http.py
# 	 File: brain_hypothesis.py
# 	 File: brain_io.py
# 	 File: brain_mechanize.py
# 	 File: brain_multiprocessing.py
# 	 File: brain_namedtuple_enum.py
# 	 File: brain_nose.py
# 	 File: brain_numpy_core_fromnumeric.py
# 	 File: brain_numpy_core_function_base.py
# 	 File: brain_numpy_core_multiarray.py
# 	 File: brain_numpy_core_numeric.py
# 	 File: brain_numpy_core_numerictypes.py
# 	 File: brain_numpy_core_umath.py
# 	 File: brain_numpy_ma.py
# 	 File: brain_numpy_ndarray.py
# 	 File: brain_numpy_random_mtrand.py
# 	 File: brain_numpy_utils.py
# 	 File: brain_pkg_resources.py
# 	 File: brain_pytest.py
# 	 File: brain_qt.py
# 	 File: brain_random.py
# 	 File: brain_re.py
# 	 File: brain_responses.py
# 	 File: brain_scipy_signal.py
# 	 File: brain_signal.py
# 	 File: brain_six.py
# 	 File: brain_sqlalchemy.py
# 	 File: brain_ssl.py
# 	 File: brain_subprocess.py
# 	 File: brain_threading.py
# 	 File: brain_type.py
# 	 File: brain_typing.py
# 	 File: brain_unittest.py
# 	 File: brain_uuid.py
# 	 File: helpers.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\astroid\brain\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: brain_argparse.cpython-39.pyc
# 	 File: brain_attrs.cpython-39.pyc
# 	 File: brain_boto3.cpython-39.pyc
# 	 File: brain_builtin_inference.cpython-39.pyc
# 	 File: brain_collections.cpython-39.pyc
# 	 File: brain_crypt.cpython-39.pyc
# 	 File: brain_ctypes.cpython-39.pyc
# 	 File: brain_curses.cpython-39.pyc
# 	 File: brain_dataclasses.cpython-39.pyc
# 	 File: brain_dateutil.cpython-39.pyc
# 	 File: brain_fstrings.cpython-39.pyc
# 	 File: brain_functools.cpython-39.pyc
# 	 File: brain_gi.cpython-39.pyc
# 	 File: brain_hashlib.cpython-39.pyc
# 	 File: brain_http.cpython-39.pyc
# 	 File: brain_hypothesis.cpython-39.pyc
# 	 File: brain_io.cpython-39.pyc
# 	 File: brain_mechanize.cpython-39.pyc
# 	 File: brain_multiprocessing.cpython-39.pyc
# 	 File: brain_namedtuple_enum.cpython-39.pyc
# 	 File: brain_nose.cpython-39.pyc
# 	 File: brain_numpy_core_fromnumeric.cpython-39.pyc
# 	 File: brain_numpy_core_function_base.cpython-39.pyc
# 	 File: brain_numpy_core_multiarray.cpython-39.pyc
# 	 File: brain_numpy_core_numeric.cpython-39.pyc
# 	 File: brain_numpy_core_numerictypes.cpython-39.pyc
# 	 File: brain_numpy_core_umath.cpython-39.pyc
# 	 File: brain_numpy_ma.cpython-39.pyc
# 	 File: brain_numpy_ndarray.cpython-39.pyc
# 	 File: brain_numpy_random_mtrand.cpython-39.pyc
# 	 File: brain_numpy_utils.cpython-39.pyc
# 	 File: brain_pkg_resources.cpython-39.pyc
# 	 File: brain_pytest.cpython-39.pyc
# 	 File: brain_qt.cpython-39.pyc
# 	 File: brain_random.cpython-39.pyc
# 	 File: brain_re.cpython-39.pyc
# 	 File: brain_responses.cpython-39.pyc
# 	 File: brain_scipy_signal.cpython-39.pyc
# 	 File: brain_signal.cpython-39.pyc
# 	 File: brain_six.cpython-39.pyc
# 	 File: brain_sqlalchemy.cpython-39.pyc
# 	 File: brain_ssl.cpython-39.pyc
# 	 File: brain_subprocess.cpython-39.pyc
# 	 File: brain_threading.cpython-39.pyc
# 	 File: brain_type.cpython-39.pyc
# 	 File: brain_typing.cpython-39.pyc
# 	 File: brain_unittest.cpython-39.pyc
# 	 File: brain_uuid.cpython-39.pyc
# 	 File: helpers.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\astroid\interpreter
#
#
# The subfolders are:
# 	 Subfolder _import
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: dunder_lookup.py
# 	 File: objectmodel.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\astroid\interpreter\_import
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: spec.py
# 	 File: util.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\astroid\interpreter\_import\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: spec.cpython-39.pyc
# 	 File: util.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\astroid\interpreter\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: dunder_lookup.cpython-39.pyc
# 	 File: objectmodel.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\astroid\nodes
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: as_string.py
# 	 File: const.py
# 	 File: node_classes.py
# 	 File: node_ng.py
# 	 File: scoped_nodes.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\astroid\nodes\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: as_string.cpython-39.pyc
# 	 File: const.cpython-39.pyc
# 	 File: node_classes.cpython-39.pyc
# 	 File: node_ng.cpython-39.pyc
# 	 File: scoped_nodes.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\astroid\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: arguments.cpython-39.pyc
# 	 File: astroid_manager.cpython-39.pyc
# 	 File: bases.cpython-39.pyc
# 	 File: builder.cpython-39.pyc
# 	 File: const.cpython-39.pyc
# 	 File: context.cpython-39.pyc
# 	 File: decorators.cpython-39.pyc
# 	 File: exceptions.cpython-39.pyc
# 	 File: helpers.cpython-39.pyc
# 	 File: inference.cpython-39.pyc
# 	 File: inference_tip.cpython-39.pyc
# 	 File: manager.cpython-39.pyc
# 	 File: mixins.cpython-39.pyc
# 	 File: modutils.cpython-39.pyc
# 	 File: node_classes.cpython-39.pyc
# 	 File: objects.cpython-39.pyc
# 	 File: protocols.cpython-39.pyc
# 	 File: raw_building.cpython-39.pyc
# 	 File: rebuilder.cpython-39.pyc
# 	 File: scoped_nodes.cpython-39.pyc
# 	 File: test_utils.cpython-39.pyc
# 	 File: transforms.cpython-39.pyc
# 	 File: util.cpython-39.pyc
# 	 File: _ast.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
# 	 File: __pkginfo__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\astroid-2.9.0.dist-info
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: INSTALLER
# 	 File: LICENSE
# 	 File: METADATA
# 	 File: RECORD
# 	 File: top_level.txt
# 	 File: WHEEL
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\backcall
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: backcall.py
# 	 File: _signatures.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\backcall\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: backcall.cpython-39.pyc
# 	 File: _signatures.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\backcall-0.2.0.dist-info
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: INSTALLER
# 	 File: LICENSE
# 	 File: METADATA
# 	 File: RECORD
# 	 File: WHEEL
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\black
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: brackets.py
# 	 File: cache.py
# 	 File: comments.py
# 	 File: concurrency.py
# 	 File: const.py
# 	 File: debug.py
# 	 File: files.py
# 	 File: handle_ipynb_magics.py
# 	 File: linegen.py
# 	 File: lines.py
# 	 File: mode.py
# 	 File: nodes.py
# 	 File: numerics.py
# 	 File: output.py
# 	 File: parsing.py
# 	 File: py.typed
# 	 File: report.py
# 	 File: rusty.py
# 	 File: strings.py
# 	 File: trans.py
# 	 File: __init__.py
# 	 File: __main__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\black\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: brackets.cpython-39.pyc
# 	 File: cache.cpython-39.pyc
# 	 File: comments.cpython-39.pyc
# 	 File: concurrency.cpython-39.pyc
# 	 File: const.cpython-39.pyc
# 	 File: debug.cpython-39.pyc
# 	 File: files.cpython-39.pyc
# 	 File: handle_ipynb_magics.cpython-39.pyc
# 	 File: linegen.cpython-39.pyc
# 	 File: lines.cpython-39.pyc
# 	 File: mode.cpython-39.pyc
# 	 File: nodes.cpython-39.pyc
# 	 File: numerics.cpython-39.pyc
# 	 File: output.cpython-39.pyc
# 	 File: parsing.cpython-39.pyc
# 	 File: report.cpython-39.pyc
# 	 File: rusty.cpython-39.pyc
# 	 File: strings.cpython-39.pyc
# 	 File: trans.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
# 	 File: __main__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\black-21.12b0.dist-info
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: AUTHORS.md
# 	 File: entry_points.txt
# 	 File: INSTALLER
# 	 File: LICENSE
# 	 File: METADATA
# 	 File: RECORD
# 	 File: REQUESTED
# 	 File: top_level.txt
# 	 File: WHEEL
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\blackd
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: middlewares.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\blackd\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: middlewares.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\black_primer
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: cli.py
# 	 File: lib.py
# 	 File: primer.json
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\black_primer\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: cli.cpython-39.pyc
# 	 File: lib.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\blib2to3
#
#
# The subfolders are:
# 	 Subfolder pgen2
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: Grammar.txt
# 	 File: PatternGrammar.txt
# 	 File: pygram.py
# 	 File: pytree.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\blib2to3\pgen2
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: conv.py
# 	 File: driver.py
# 	 File: grammar.py
# 	 File: literals.py
# 	 File: parse.py
# 	 File: pgen.py
# 	 File: token.py
# 	 File: tokenize.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\blib2to3\pgen2\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: conv.cpython-39.pyc
# 	 File: driver.cpython-39.pyc
# 	 File: grammar.cpython-39.pyc
# 	 File: literals.cpython-39.pyc
# 	 File: parse.cpython-39.pyc
# 	 File: pgen.cpython-39.pyc
# 	 File: token.cpython-39.pyc
# 	 File: tokenize.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\blib2to3\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: pygram.cpython-39.pyc
# 	 File: pytree.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\click
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: core.py
# 	 File: decorators.py
# 	 File: exceptions.py
# 	 File: formatting.py
# 	 File: globals.py
# 	 File: parser.py
# 	 File: py.typed
# 	 File: shell_completion.py
# 	 File: termui.py
# 	 File: testing.py
# 	 File: types.py
# 	 File: utils.py
# 	 File: _compat.py
# 	 File: _termui_impl.py
# 	 File: _textwrap.py
# 	 File: _unicodefun.py
# 	 File: _winconsole.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\click\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: core.cpython-39.pyc
# 	 File: decorators.cpython-39.pyc
# 	 File: exceptions.cpython-39.pyc
# 	 File: formatting.cpython-39.pyc
# 	 File: globals.cpython-39.pyc
# 	 File: parser.cpython-39.pyc
# 	 File: shell_completion.cpython-39.pyc
# 	 File: termui.cpython-39.pyc
# 	 File: testing.cpython-39.pyc
# 	 File: types.cpython-39.pyc
# 	 File: utils.cpython-39.pyc
# 	 File: _compat.cpython-39.pyc
# 	 File: _termui_impl.cpython-39.pyc
# 	 File: _textwrap.cpython-39.pyc
# 	 File: _unicodefun.cpython-39.pyc
# 	 File: _winconsole.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\click-8.0.3.dist-info
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: INSTALLER
# 	 File: LICENSE.rst
# 	 File: METADATA
# 	 File: RECORD
# 	 File: top_level.txt
# 	 File: WHEEL
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\colorama
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: ansi.py
# 	 File: ansitowin32.py
# 	 File: initialise.py
# 	 File: win32.py
# 	 File: winterm.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\colorama\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: ansi.cpython-39.pyc
# 	 File: ansitowin32.cpython-39.pyc
# 	 File: initialise.cpython-39.pyc
# 	 File: win32.cpython-39.pyc
# 	 File: winterm.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\colorama-0.4.4.dist-info
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: INSTALLER
# 	 File: LICENSE.txt
# 	 File: METADATA
# 	 File: RECORD
# 	 File: top_level.txt
# 	 File: WHEEL
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\dateutil
#
#
# The subfolders are:
# 	 Subfolder parser
# 	 Subfolder tz
# 	 Subfolder zoneinfo
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: easter.py
# 	 File: relativedelta.py
# 	 File: rrule.py
# 	 File: tzwin.py
# 	 File: utils.py
# 	 File: _common.py
# 	 File: _version.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\dateutil\parser
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: isoparser.py
# 	 File: _parser.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\dateutil\parser\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: isoparser.cpython-39.pyc
# 	 File: _parser.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\dateutil\tz
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: tz.py
# 	 File: win.py
# 	 File: _common.py
# 	 File: _factories.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\dateutil\tz\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: tz.cpython-39.pyc
# 	 File: win.cpython-39.pyc
# 	 File: _common.cpython-39.pyc
# 	 File: _factories.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\dateutil\zoneinfo
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: dateutil-zoneinfo.tar.gz
# 	 File: rebuild.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\dateutil\zoneinfo\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: rebuild.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\dateutil\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: easter.cpython-39.pyc
# 	 File: relativedelta.cpython-39.pyc
# 	 File: rrule.cpython-39.pyc
# 	 File: tzwin.cpython-39.pyc
# 	 File: utils.cpython-39.pyc
# 	 File: _common.cpython-39.pyc
# 	 File: _version.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\debugpy
#
#
# The subfolders are:
# 	 Subfolder adapter
# 	 Subfolder common
# 	 Subfolder launcher
# 	 Subfolder server
# 	 Subfolder _vendored
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: ThirdPartyNotices.txt
# 	 File: _version.py
# 	 File: __init__.py
# 	 File: __main__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\debugpy\adapter
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: clients.py
# 	 File: components.py
# 	 File: launchers.py
# 	 File: servers.py
# 	 File: sessions.py
# 	 File: __init__.py
# 	 File: __main__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\debugpy\adapter\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: clients.cpython-39.pyc
# 	 File: components.cpython-39.pyc
# 	 File: launchers.cpython-39.pyc
# 	 File: servers.cpython-39.pyc
# 	 File: sessions.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
# 	 File: __main__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\debugpy\common
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: compat.py
# 	 File: fmt.py
# 	 File: json.py
# 	 File: log.py
# ...
# 	 File: monitoredqueue.cpython-39.pyc
# 	 File: monitoredqueuedevice.cpython-39.pyc
# 	 File: proxydevice.cpython-39.pyc
# 	 File: proxysteerabledevice.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\eventloop
#
#
# The subfolders are:
# 	 Subfolder minitornado
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: future.py
# 	 File: ioloop.py
# 	 File: zmqstream.py
# 	 File: _deprecated.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\eventloop\minitornado
#
#
# The subfolders are:
# 	 Subfolder platform
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: concurrent.py
# 	 File: ioloop.py
# 	 File: log.py
# 	 File: stack_context.py
# 	 File: util.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\eventloop\minitornado\platform
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: auto.py
# 	 File: common.py
# 	 File: interface.py
# 	 File: posix.py
# 	 File: windows.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\eventloop\minitornado\platform\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: auto.cpython-39.pyc
# 	 File: common.cpython-39.pyc
# 	 File: interface.cpython-39.pyc
# 	 File: posix.cpython-39.pyc
# 	 File: windows.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\eventloop\minitornado\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: concurrent.cpython-39.pyc
# 	 File: ioloop.cpython-39.pyc
# 	 File: log.cpython-39.pyc
# 	 File: stack_context.cpython-39.pyc
# 	 File: util.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\eventloop\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: future.cpython-39.pyc
# 	 File: ioloop.cpython-39.pyc
# 	 File: zmqstream.cpython-39.pyc
# 	 File: _deprecated.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\green
#
#
# The subfolders are:
# 	 Subfolder eventloop
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: core.py
# 	 File: device.py
# 	 File: poll.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\green\eventloop
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: ioloop.py
# 	 File: zmqstream.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\green\eventloop\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: ioloop.cpython-39.pyc
# 	 File: zmqstream.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\green\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: core.cpython-39.pyc
# 	 File: device.cpython-39.pyc
# 	 File: poll.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\log
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: handlers.py
# 	 File: __init__.py
# 	 File: __main__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\log\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: handlers.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
# 	 File: __main__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\ssh
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: forward.py
# 	 File: tunnel.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\ssh\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: forward.cpython-39.pyc
# 	 File: tunnel.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\sugar
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: attrsettr.py
# 	 File: constants.py
# 	 File: constants.pyi
# 	 File: context.py
# 	 File: frame.py
# 	 File: poll.py
# 	 File: socket.py
# 	 File: stopwatch.py
# 	 File: tracker.py
# 	 File: version.py
# 	 File: __init__.py
# 	 File: __init__.pyi
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\sugar\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: attrsettr.cpython-39.pyc
# 	 File: constants.cpython-39.pyc
# 	 File: context.cpython-39.pyc
# 	 File: frame.cpython-39.pyc
# 	 File: poll.cpython-39.pyc
# 	 File: socket.cpython-39.pyc
# 	 File: stopwatch.cpython-39.pyc
# 	 File: tracker.cpython-39.pyc
# 	 File: version.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\tests
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: conftest.py
# 	 File: test_asyncio.py
# 	 File: test_auth.py
# 	 File: test_cffi_backend.py
# 	 File: test_constants.py
# 	 File: test_context.py
# 	 File: test_cython.py
# 	 File: test_decorators.py
# 	 File: test_device.py
# 	 File: test_draft.py
# 	 File: test_error.py
# 	 File: test_etc.py
# 	 File: test_future.py
# 	 File: test_imports.py
# 	 File: test_includes.py
# 	 File: test_ioloop.py
# 	 File: test_log.py
# 	 File: test_message.py
# 	 File: test_monitor.py
# 	 File: test_monqueue.py
# 	 File: test_multipart.py
# 	 File: test_mypy.py
# 	 File: test_pair.py
# 	 File: test_poll.py
# 	 File: test_proxy_steerable.py
# 	 File: test_pubsub.py
# 	 File: test_reqrep.py
# 	 File: test_retry_eintr.py
# 	 File: test_security.py
# 	 File: test_socket.py
# 	 File: test_ssh.py
# 	 File: test_version.py
# 	 File: test_win32_shim.py
# 	 File: test_z85.py
# 	 File: test_zmqstream.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\tests\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: conftest.cpython-39.pyc
# 	 File: test_asyncio.cpython-39.pyc
# 	 File: test_auth.cpython-39.pyc
# 	 File: test_cffi_backend.cpython-39.pyc
# 	 File: test_constants.cpython-39.pyc
# 	 File: test_context.cpython-39.pyc
# 	 File: test_cython.cpython-39.pyc
# 	 File: test_decorators.cpython-39.pyc
# 	 File: test_device.cpython-39.pyc
# 	 File: test_draft.cpython-39.pyc
# 	 File: test_error.cpython-39.pyc
# 	 File: test_etc.cpython-39.pyc
# 	 File: test_future.cpython-39.pyc
# 	 File: test_imports.cpython-39.pyc
# 	 File: test_includes.cpython-39.pyc
# 	 File: test_ioloop.cpython-39.pyc
# 	 File: test_log.cpython-39.pyc
# 	 File: test_message.cpython-39.pyc
# 	 File: test_monitor.cpython-39.pyc
# 	 File: test_monqueue.cpython-39.pyc
# 	 File: test_multipart.cpython-39.pyc
# 	 File: test_mypy.cpython-39.pyc
# 	 File: test_pair.cpython-39.pyc
# 	 File: test_poll.cpython-39.pyc
# 	 File: test_proxy_steerable.cpython-39.pyc
# 	 File: test_pubsub.cpython-39.pyc
# 	 File: test_reqrep.cpython-39.pyc
# 	 File: test_retry_eintr.cpython-39.pyc
# 	 File: test_security.cpython-39.pyc
# 	 File: test_socket.cpython-39.pyc
# 	 File: test_ssh.cpython-39.pyc
# 	 File: test_version.cpython-39.pyc
# 	 File: test_win32_shim.cpython-39.pyc
# 	 File: test_z85.cpython-39.pyc
# 	 File: test_zmqstream.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\utils
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: buffers.pxd
# 	 File: compiler.json
# 	 File: config.json
# 	 File: constant_names.py
# 	 File: garbage.py
# 	 File: getpid_compat.h
# 	 File: interop.py
# 	 File: ipcmaxlen.h
# 	 File: jsonapi.py
# 	 File: monitor.py
# 	 File: mutex.h
# 	 File: pyversion_compat.h
# 	 File: strtypes.py
# 	 File: win32.py
# 	 File: z85.py
# 	 File: zmq_compat.h
# 	 File: zmq_constants.h
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\utils\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: constant_names.cpython-39.pyc
# 	 File: garbage.cpython-39.pyc
# 	 File: interop.cpython-39.pyc
# 	 File: jsonapi.cpython-39.pyc
# 	 File: monitor.cpython-39.pyc
# 	 File: strtypes.cpython-39.pyc
# 	 File: win32.cpython-39.pyc
# 	 File: z85.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\zmq\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: asyncio.cpython-39.pyc
# 	 File: decorators.cpython-39.pyc
# 	 File: error.cpython-39.pyc
# 	 File: _future.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\_distutils_hack
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: override.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\_distutils_hack\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: override.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Lib\site-packages\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: decorator.cpython-39.pyc
# 	 File: entrypoints.cpython-39.pyc
# 	 File: ipykernel_launcher.cpython-39.pyc
# 	 File: jupyter.cpython-39.pyc
# 	 File: mccabe.cpython-39.pyc
# 	 File: mypy_extensions.cpython-39.pyc
# 	 File: nest_asyncio.cpython-39.pyc
# 	 File: pickleshare.cpython-39.pyc
# 	 File: pythoncom.cpython-39.pyc
# 	 File: six.cpython-39.pyc
# 	 File: typing_extensions.cpython-39.pyc
# 	 File: _black_version.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Scripts
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: activate
# 	 File: activate.bat
# 	 File: Activate.ps1
# 	 File: black-primer.exe
# 	 File: black.exe
# 	 File: blackd.exe
# 	 File: deactivate.bat
# 	 File: epylint.exe
# 	 File: f2py.exe
# 	 File: iptest.exe
# 	 File: iptest3.exe
# 	 File: ipython.exe
# 	 File: ipython3.exe
# 	 File: isort-identify-imports.exe
# 	 File: isort.exe
# 	 File: jupyter-kernel.exe
# 	 File: jupyter-kernelspec.exe
# 	 File: jupyter-migrate.exe
# 	 File: jupyter-run.exe
# 	 File: jupyter-troubleshoot.exe
# 	 File: jupyter.exe
# 	 File: pip.exe
# 	 File: pip3.9.exe
# 	 File: pip3.exe
# 	 File: pygmentize.exe
# 	 File: pylint.exe
# 	 File: pyreverse.exe
# 	 File: python.exe
# 	 File: pythonw.exe
# 	 File: pywin32_postinstall.py
# 	 File: pywin32_testall.py
# 	 File: send2trash.exe
# 	 File: symilar.exe
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\Scripts\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: pywin32_postinstall.cpython-39.pyc
# 	 File: pywin32_testall.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\share
#
#
# The subfolders are:
# 	 Subfolder jupyter
# 	 Subfolder man
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\share\jupyter
#
#
# The subfolders are:
# 	 Subfolder kernels
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\share\jupyter\kernels
#
#
# The subfolders are:
# 	 Subfolder python3
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\share\jupyter\kernels\python3
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: kernel.json
# 	 File: logo-32x32.png
# 	 File: logo-64x64.png
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\share\man
#
#
# The subfolders are:
# 	 Subfolder man1
#
#
# The files are:
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\env\share\man\man1
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: ipython.1.gz
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p10_name_and_main
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: one.py
# 	 File: two.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p10_name_and_main\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: one.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p11_error_handling
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: 02-Errors and Exceptions Homework.ipynb
# 	 File: cap.py
# 	 File: error_handling.ipynb
# 	 File: simple1.py
# 	 File: testfile.txt
# 	 File: test_cap.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p11_error_handling\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: cap.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p12_blackjack_project
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 02-blackjack_walkthrough.ipynb
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p13_decorators
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: decorators.ipynb
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p14_generators
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 02-iterators_generators_homework.ipynb
# 	 File: generators.ipynb
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p15_advanced_modules
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: advanced_modules.ipynb
# 	 File: shutil_and_os_modules.ipynb
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p4_objects_and_data_structures
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 09-Objects and Data Structures Assessment Test.ipynb
# 	 File: IO_Tutorial.ipynb
# 	 File: myfile.txt
# 	 File: my_new_file.txt
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p5_statements
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: python_statements.ipynb
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p6_methods_and_functions
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 03-function_exercises.ipynb
# 	 File: 08-Functions and Methods Homework.ipynb
# 	 File: methods_and_functions.ipynb
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p8_OOP
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: 02-OOP_homework.ipynb
# 	 File: 04-OOP Challenge.ipynb
# 	 File: object_oriented_programming.ipynb
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p9_MyMainPackage
#
#
# The subfolders are:
# 	 Subfolder SubPackage
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: some_main_script.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p9_MyMainPackage\SubPackage
#
#
# The subfolders are:
# 	 Subfolder __pycache__
#
#
# The files are:
# 	 File: mysubscript.py
# 	 File: __init__.py
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p9_MyMainPackage\SubPackage\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: mysubscript.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
#
#
# Currently looking at c:\Users\James\Desktop\Python_Bootcamp\Python_Bootcamp_Notebooks\p9_MyMainPackage\__pycache__
#
#
# The subfolders are:
#
#
# The files are:
# 	 File: mymodule.cpython-39.pyc
# 	 File: some_main_script.cpython-39.pyc
# 	 File: __init__.cpython-39.pyc
